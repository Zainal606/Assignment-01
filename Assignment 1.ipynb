# %%
import pandas as pd

# %% [markdown]
# # 1. Read the dataset to python environment.

# %%
data=pd.read_excel('/Users/zainal.hameed/Downloads/iris.xls')

# %%
data
# Out:
#       SL   SW   PL   PW  Classification
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# # 2. Display the columns in the dataset.

# %%
data.columns
# Out:
# Index(['SL', 'SW', 'PL', 'PW', 'Classification'], dtype='object')

# %% [markdown]
# # 3. Calculate the mean of each column of the dataset.

# %%
mean=data.mean()
# Out:
# /var/folders/_n/1lkh44610574_m504zly5jx00000gp/T/ipykernel_9297/125936707.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   mean=data.mean()

# %%
mean
# Out:
# SL    5.843333
# SW    3.054000
# PL    3.758667
# PW    1.198667
# dtype: float64

# %% [markdown]
# # 4. Check for the null values present in the dataset.

# %%
data.isna().sum()
# Out:
# SL                0
# SW                0
# PL                0
# PW                0
# Classification    0
# dtype: int64

# %% [markdown]
# # 5. Perform meaningful visualizations using the dataset. Bring at least 3 visualizations.

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Count Plot using Sepal Width

# %%
plt.figure(figsize=(8,5))
sns.countplot(x=data['SW'])
plt.xticks(rotation = 45)
plt.xlabel('Sepal Width')
plt.show()

# %% [markdown]
# # Scatter Plot using Petal Length vs Petal Width

# %%
sns.scatterplot(x = 'PL', y = 'PW', data = data, hue = 'Classification')
plt.title('Petal Length vs Petal Width')
plt.show()

# %% [markdown]
# # Petal length vs Classification using barplot

# %%
plt.bar(data['Classification'],data['PL'])
plt.xlabel('Classification')
plt.ylabel('Petal Length')
plt.title('Petal Length for diff classifiaction')
plt.show()
